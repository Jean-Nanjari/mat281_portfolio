# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281_2022/blob/main/labs/lab_05/lab_05.ipynb
# " target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # MAT281 - Laboratorio N°05

# %% [markdown]
# ## Problema 01
# <img src="https://storage.googleapis.com/kaggle-datasets-images/19/19/default-backgrounds/dataset-card.jpg" width="360" height="360" align="center"/>

# %% [markdown]
# El **Iris dataset** es un conjunto de datos que contine una  muestras de tres especies de Iris (Iris setosa, Iris virginica e Iris versicolor). Se midió cuatro rasgos de cada muestra: el largo y ancho del sépalo y pétalo, en centímetros.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
# librerias
 
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option('display.max_columns', 500)  # Ver más columnas de los dataframes


# Ver gráficos de matplotlib en jupyter notebook/lab
# %matplotlib inline

# %%
# cargar datos
df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281_2022/main/labs/lab_05/data/iris_contaminados.csv")
df.columns = ['sepalLength',
                  'sepalWidth',
                  'petalLength',
                  'petalWidth',
                  'species']

df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth     species
# 0            4.4         3.2          1.3         3.0      setosa
# 1            7.2         3.6          6.1         2.5   virginica
# 2            6.3         3.3          6.0         2.5   VIRGINICA
# 3            6.7         3.3          5.7         2.5   virginica
# 4            6.3         3.4          5.6         2.4   virginica
# ..           ...         ...          ...         ...         ...
# 145          5.3         3.0          1.1         0.1      Setosa
# 146          4.8         3.0          1.4         0.1      Setosa
# 147          4.9         3.1          1.5         0.1      Setosa
# 148          4.9         3.6          1.4         0.1      setosa
# 149          5.2         4.1          1.5         0.1      setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Bases del experimento
#
# Lo primero es identificar las variables que influyen en el estudio y la naturaleza de esta.
#
# * **species**:
#     * Descripción: Nombre de la especie de Iris.
#     * Tipo de dato: *string*
#     * Limitantes: solo existen tres tipos (setosa, virginia y versicolor).
# * **sepalLength**:
#     * Descripción: largo del sépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 4.0 y 7.0 cm.
# * **sepalWidth**:
#     * Descripción: ancho del sépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 2.0 y 4.5 cm.
# * **petalLength**:
#     * Descripción: largo del pétalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 1.0 y 7.0 cm.
# * **petalWidth**:
#     * Descripción: ancho del pépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 0.1 y 2.5 cm.

# %% [markdown]
# Su objetivo es realizar un correcto **E.D.A.**, para esto debe seguir las siguientes intrucciones:

# %% [markdown]
# 1. Realizar un conteo de elementos de la columna **species** y corregir según su criterio. Reemplace por "default" los valores nan..

# %%
df['species'] = df['species'].str.lower().str.strip() 
df['species'].fillna("default", inplace = True)
len(df['species'].unique()) #<---cantidad de especies
# Out:
# 4

# %% [markdown]
# 2. Realizar un gráfico de box-plot sobre el largo y ancho de los petalos y sépalos. Reemplace por **0** los valores nan.

# %%
df ['sepalLength'] = df ['sepalLength']. fillna(0.0)
df ['sepalWidth'] = df ['sepalWidth']. fillna(0.0)
df ['petalLength'] = df ['petalLength']. fillna(0.0)
df ['petalWidth'] = df ['petalWidth']. fillna(0.0)
sns.boxplot(data=df)
plt.title('Tamaño y Ancho de los pétalos y sépalos') 
plt.ylabel('tamaño en [cm]')
plt.show()

# %% [markdown]
# 3. Anteriormente se define un rango de valores válidos para los valores del largo y ancho de los petalos y sépalos. Agregue una columna denominada **label**  que identifique cuál de estos valores esta fuera del rango de valores válidos.

# %%
label = []
Sl = df['sepalLength']
Sw = df['sepalWidth']
Pl = df['petalLength']
Pw = df['petalWidth']
for k in range(len(df)): 
  if (Sl[k]>7.0 or Sl[k]<4.0):
    label.append('out of range')
  elif (Sw[k]>4.5 or Sw[k]<2.0):
    label.append('out of range')
  elif (Pl[k]>7.0 or Pl[k]<1.0):
    label.append('out of range')
  elif (Pw[k]>2.5 or Pw[k]<0.1):
    label.append('out of range')
  else:
    label.append('in to range')
df["label"]=label
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species         label
# 0            4.4         3.2          1.3         3.0     setosa  out of range
# 1            7.2         3.6          6.1         2.5  virginica  out of range
# 2            6.3         3.3          6.0         2.5  virginica   in to range
# 3            6.7         3.3          5.7         2.5  virginica   in to range
# 4            6.3         3.4          5.6         2.4  virginica   in to range
# ..           ...         ...          ...         ...        ...           ...
# 145          5.3         3.0          1.1         0.1     setosa   in to range
# 146          4.8         3.0          1.4         0.1     setosa   in to range
# 147          4.9         3.1          1.5         0.1     setosa   in to range
# 148          4.9         3.6          1.4         0.1     setosa   in to range
# 149          5.2         4.1          1.5         0.1     setosa   in to range
#
# [150 rows x 6 columns]

# %% [markdown]
# 4. Realice un gráfico de *sepalLength* vs *petalLength* y otro de *sepalWidth* vs *petalWidth* categorizados por la etiqueta **label**. Concluya sus resultados.

# %%
sns.scatterplot(x='sepalLength', y='petalLength', hue='label', data=df)
plt.title('sepalLength vs petalLength')
plt.show()

# %%
sns.scatterplot(x='sepalWidth', y='petalWidth', hue='label', data=df)
plt.title('sepalWidth vs petalWidth')
plt.show()

# %% [markdown]
# 5. Filtre los datos válidos y realice un gráfico de *sepalLength* vs *petalLength* categorizados por la etiqueta **species**.
